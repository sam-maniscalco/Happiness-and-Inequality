# %%
import pandas as pd
import matplotlib.pyplot as plt
import datetime
import numpy as np

# %matplotlib inline
plt.figure(figsize=(24,24))

import matplotlib.style as style
style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
W = pd.read_csv("h&e_Summary.csv")

# %%
W= W.set_index('Year')
W
# Out:
#       United  States  United Kingdom  China  Norway  Bhutan  India  Ethiopia
# Year
# 2015           7.119           6.867  5.140   7.522   5.253  4.565     4.512
# 2016           7.104           6.725  5.245   7.498   5.196  4.404     4.508
# 2017           6.993           6.714  5.273   7.537   5.011  4.315     4.460
# 2018           6.886           7.190  5.246   7.594   5.082  4.190     4.350
# 2019           6.892           7.054  5.191   7.554   5.082  4.015     4.286

# %%
W=W.rename(columns={"United  States":"US"})
W=W.rename(columns={"United Kingdom":"UK"})
W
# Out:
#          US     UK  China  Norway  Bhutan  India  Ethiopia
# Year
# 2015  7.119  6.867  5.140   7.522   5.253  4.565     4.512
# 2016  7.104  6.725  5.245   7.498   5.196  4.404     4.508
# 2017  6.993  6.714  5.273   7.537   5.011  4.315     4.460
# 2018  6.886  7.190  5.246   7.594   5.082  4.190     4.350
# 2019  6.892  7.054  5.191   7.554   5.082  4.015     4.286

# %%
plt.style.use("fivethirtyeight")
plt.figure(figsize=(12,6))
plt.plot(W.US,linestyle='--',marker="x")
plt.plot(W.UK,linestyle=":", marker="o")
plt.plot(W.China, linestyle=(0,(5,4,1,2)),marker="+")
plt.plot(W.Norway, linestyle=(0,(5,4,1,2)),marker=".")
plt.plot(W.Bhutan, linestyle=(0,(5,4,1,2)),marker="o")
plt.plot(W.India, linestyle="-",marker="+")
plt.plot(W.Ethiopia, linestyle="-",marker=".")

plt.legend(['United States','United Kingdom','China','Norway','Bhutan','India',"Ethiopia"],bbox_to_anchor=[0.95,0.95])


plt.title("Happiess of different countries over time")
plt.xlabel("Time")
plt.ylabel("Happiness score")
# Out:
# Text(0, 0.5, 'Happiness score')

# %%
M= pd.read_csv("2017.csv")
import seaborn as sns
plt.figure(figsize=(8,8))
corrMatrix= M.corr()
sns.heatmap(corrMatrix, annot=True, cmap=sns.diverging_palette(200,8, as_cmap=True))

# %%
K= pd.read_csv("Coefficient of Human Inequality_3.csv")
K=K.set_index("Country")
K
# Out:
#                                                     2010  2011  2012  2013  \
# Country
# Afghanistan                                           ..    ..    ..    30
# Albania                                             12.7  13.8  13.8  13.4
# Algeria                                               ..    ..    ..    ..
# Angola                                              38.8    ..  43.6  43.6
# Argentina                                             19  18.7  18.7  15.3
# ...                                                  ...   ...   ...   ...
# Sub-Saharan Africa                                  34.7  34.3  34.9  33.6
# Least Developed Countries                             33  32.3  32.4    31
# Small Island Developing States                      28.7  27.5  28.3  24.4
# Organization for Economic Co-operation and Deve...  12.1  12.8  12.3    13
# World                                               23.4  22.9  23.2  22.9
#
# ...

# %%
K_t=K.T
K_t
# Out:
# Country Afghanistan Albania Algeria Angola Argentina Armenia Australia  \
# 2010             ..    12.7      ..   38.8        19    10.9       7.7
# 2011             ..    13.8      ..     ..      18.7    10.7       7.7
# 2012             ..    13.8      ..   43.6      18.7    10.8       7.7
# 2013             30    13.4      ..   43.6      15.3    10.2       7.5
# 2014             30    13.4      ..   36.6      14.6    10.1       7.9
# 2015           30.4    13.4      ..   36.6      15.2     9.2         8
# 2016           28.2    12.2      ..   32.4        14     8.6       8.3
# 2017           28.2      10    20.1   32.3      13.8     9.8         8
# 2018             ..    10.9    19.7   31.7      13.6     9.7       7.9
#
# Country Austria Azerbaijan Bahamas  ... Arab States East Asia and the Pacific  \
# 2010        7.3       13.4      14  ...        26.5                      21.7
# 2011        7.2       11.1    14.4  ...        25.3                      21.1
# ...

# %%
K_t=K_t.rename(columns={"United States":"US"})
K_t=K_t.rename(columns={"United Kingdom":"UK"})
K_t['US'] = K_t['US'].astype(float)
K_t['UK'] = K_t['UK'].astype(float)
K_t['India'] = K_t['India'].astype(float)
#K_t['China'] = K_t['China'].astype(float), errors="coerce"
K_t['China'] = pd.to_numeric(K_t['China'], errors='coerce')
K_t['Bhutan'] = pd.to_numeric(K_t['Bhutan'], errors='coerce')
#K_t['Bhutan'] = K_t['Bhutan'].astype(float)
K_t['Norway'] = K_t['Norway'].astype(float)
K_t['Ethiopia'] = K_t['Ethiopia'].astype(float)

# %%
plt.style.use('seaborn-whitegrid')
fig=plt.figure(figsize=(6,6))
fig=plt.plot(K_t.US ,linestyle='--',marker="o")
fig= plt.plot(K_t.UK,linestyle='--',marker="x")
fig= plt.plot(K_t.China,linestyle=(0,(5,4,1,2)),marker=".")
fig= plt.plot(K_t.India,linestyle=(0,(5,4,1,2)),marker="+")
fig= plt.plot(K_t.Bhutan,linestyle='--',marker="o")
fig= plt.plot(K_t.Norway,linestyle=(0,(5,4,1,2)),marker="+")
fig= plt.plot(K_t.Ethiopia,linestyle='--',marker="x")

plt.legend(['United States','United Kingdom','China','India','Bhutan','Norway',"Ethiopia"],bbox_to_anchor=[0.95,0.95])


plt.title("Coefficient of Human Inequality of selected countries over time")
plt.xlabel("Time")
plt.ylabel("Coefficient of Human Inequality")
# Out:
# Text(0, 0.5, 'Coefficient of Human Inequality')

# %%
L= pd.read_csv("final_gini_0.csv")
L=L.set_index("Country Name")
L_t=L.T
L_t
# Out:
# Country Name  Aruba  Afghanistan  Angola  Albania  Andorra  Arab World  \
# 2005            NaN          NaN     NaN     30.6      NaN         NaN
# 2006            NaN          NaN     NaN      NaN      NaN         NaN
# 2007            NaN          NaN     NaN      NaN      NaN         NaN
# 2008            NaN          NaN    42.7     30.0      NaN         NaN
# 2009            NaN          NaN     NaN      NaN      NaN         NaN
# 2010            NaN          NaN     NaN      NaN      NaN         NaN
# 2011            NaN          NaN     NaN      NaN      NaN         NaN
# 2012            NaN          NaN     NaN     29.0      NaN         NaN
# 2013            NaN          NaN     NaN      NaN      NaN         NaN
# 2014            NaN          NaN     NaN     34.6      NaN         NaN
# 2015            NaN          NaN     NaN     32.9      NaN         NaN
# 2016            NaN          NaN     NaN     33.7      NaN         NaN
# ...

# %%
L_t=L_t.rename(columns={"United States":"US"})
L_t=L_t.rename(columns={"United Kingdom":"UK"})
L_t['China'] = pd.to_numeric(L_t['China'], errors='coerce')
L_t['Bhutan'] = pd.to_numeric(L_t['Bhutan'], errors='coerce')
L_t['India'] = pd.to_numeric(L_t['India'], errors='coerce')
L_t['US'] = pd.to_numeric(L_t['US'], errors='coerce')
L_t['UK'] = pd.to_numeric(L_t['UK'], errors='coerce')
L_t['Ethiopia'] = pd.to_numeric(L_t['Ethiopia'], errors='coerce')
L_t['Norway'] = pd.to_numeric(L_t['Norway'], errors='coerce')

# %%
plt.style.use('default')
fig1=plt.figure(figsize=(6,6))
fig1=plt.plot(L_t.US ,linestyle='--',marker="o")
fig1= plt.plot(L_t.UK,linestyle='--',marker="x")
fig1= plt.plot(L_t.China,linestyle=(0,(5,4,1,2)),marker=".")
fig1= plt.plot(L_t.India,linestyle=(0,(5,4,1,2)),marker="+")
fig1= plt.plot(L_t.Bhutan,linestyle='--',marker="o")
fig1= plt.plot(L_t.Norway,linestyle=(0,(5,4,1,2)),marker="+")
fig1= plt.plot(L_t.Ethiopia,linestyle='--',marker="x")

plt.legend(['United States','United Kingdom','China','India','Bhutan','Norway',"Ethiopia"],bbox_to_anchor=[0.95,0.95])


plt.title("Gini coefficient(as %) of selected countries over time")
plt.xlabel("Time")
plt.ylabel("Gini coefficient")
# Out:
# Text(0, 0.5, 'Gini coefficient')

# %%
G= pd.read_csv("Gender Inequality Index (GII).csv")
G=G.set_index("Country")
G_t=G.T
G_t
# Out:
# Country Afghanistan Albania Algeria Angola Argentina Armenia Australia  \
# 2005          0.674   0.329   0.561     ..     0.371   0.403     0.139
# 2010          0.665   0.269   0.523     ..     0.371   0.345     0.138
# 2011          0.654   0.273   0.515     ..     0.368    0.34     0.132
# 2012          0.644   0.273   0.434     ..     0.365   0.319     0.128
# 2013          0.633   0.266   0.432     ..     0.365   0.311     0.119
# 2014          0.623   0.261   0.439  0.577     0.365   0.305     0.116
# 2015          0.614   0.256   0.442  0.575        ..   0.301      0.11
# 2016          0.605   0.249   0.439  0.572     0.359     0.3     0.107
# 2017           0.59   0.236   0.447   0.58     0.355   0.263     0.104
# 2018          0.575   0.234   0.443  0.578     0.354   0.259     0.103
#
# Country Austria Azerbaijan Bahamas  ... Arab States East Asia and the Pacific  \
# 2005      0.118      0.325    0.36  ...       0.615                     0.348
# ...

# %%
G_t=G_t.rename(columns={"United States":"US"})
G_t=G_t.rename(columns={"United Kingdom":"UK"})
G_t['China'] = pd.to_numeric(G_t['China'], errors='coerce')
G_t['Bhutan'] = pd.to_numeric(G_t['Bhutan'], errors='coerce')
G_t['India'] = pd.to_numeric(G_t['India'], errors='coerce')
G_t['US'] = pd.to_numeric(G_t['US'], errors='coerce')
G_t['UK'] = pd.to_numeric(G_t['UK'], errors='coerce')
G_t['Ethiopia'] = pd.to_numeric(G_t['Ethiopia'], errors='coerce')
G_t['Norway'] = pd.to_numeric(G_t['Norway'], errors='coerce')

# %%
plt.style.use('dark_background')
fig3=plt.figure(figsize=(8,6))
fig3=plt.plot(G_t.US ,linestyle='--',marker="o")
fig3= plt.plot(G_t.UK,linestyle='--',marker="x")
fig3= plt.plot(G_t.China,linestyle=(0,(5,4,1,2)),marker=".")
fig3= plt.plot(G_t.India,linestyle=(0,(5,4,1,2)),marker="+")
fig3= plt.plot(G_t.Bhutan,linestyle='--',marker="o")
fig3= plt.plot(G_t.Norway,linestyle=(0,(5,4,1,2)),marker="+")
fig3= plt.plot(G_t.Ethiopia,linestyle='--',marker="x")

plt.legend(['United States','United Kingdom','China','India','Bhutan','Norway',"Ethiopia"],bbox_to_anchor=[0.95,0.95])


plt.title("Gender Inequality Index of selected countries over time")
plt.xlabel("Time")
plt.ylabel("GII")
# Out:
# Text(0, 0.5, 'GII')

# %%
E= pd.read_csv("education.csv")
E= E.set_index("Country")
E_t=E.T
E_t
# Out:
# Country Afghanistan Albania Algeria Andorra Angola Argentina Armenia  \
# 2010           39.3    12.7      ..      ..   26.2      12.1     6.5
# 2011           39.3    11.9      ..      ..     ..      12.1     6.5
# 2012           39.3    11.9      ..      ..   34.6      12.1     3.7
# 2013             45    11.9      ..      ..   34.6       8.6     3.7
# 2014           44.8    11.9      ..      ..   34.6       8.1     3.7
# 2015           44.8    11.9      ..      ..   34.6       8.1     3.7
# 2016           45.4     9.1    33.7      ..   34.3       6.1     2.9
# 2017           45.4     8.5    33.7     9.4   34.3       6.2     2.9
# 2018           45.4    12.3    33.7      10   34.3       6.2     2.9
#
# Country Australia Austria Azerbaijan  ... Arab States  \
# 2010          1.7     2.4         12  ...        41.8
# 2011          1.7     2.4        8.3  ...        40.5
# 2012          1.7     2.5        8.3  ...        39.5
# 2013          1.8     3.7        8.3  ...          38
# ...

# %%
E_t=E_t.rename(columns={"United States":"US"})
E_t=E_t.rename(columns={"United Kingdom":"UK"})
E_t['China'] = pd.to_numeric(E_t['China'], errors='coerce')
E_t['Bhutan'] = pd.to_numeric(E_t['Bhutan'], errors='coerce')
E_t['India'] = pd.to_numeric(E_t['India'], errors='coerce')
E_t['US'] = pd.to_numeric(E_t['US'], errors='coerce')
E_t['UK'] = pd.to_numeric(E_t['UK'], errors='coerce')
E_t['Ethiopia'] = pd.to_numeric(E_t['Ethiopia'], errors='coerce')
E_t['Norway'] = pd.to_numeric(E_t['Norway'], errors='coerce')

# %%
plt.style.use('default')
fig1=plt.figure(figsize=(8,6))
fig1=plt.plot(E_t.US ,linestyle='--',marker="o")
fig1= plt.plot(E_t.UK,linestyle='--',marker="x")
fig1= plt.plot(E_t.China,linestyle=(0,(5,4,1,2)),marker=".")
fig1= plt.plot(E_t.India,linestyle=(0,(5,4,1,2)),marker="+")
fig1= plt.plot(E_t.Bhutan,linestyle='--',marker="o")
fig1= plt.plot(E_t.Norway,linestyle=(0,(5,4,1,2)),marker="+")
fig1= plt.plot(E_t.Ethiopia,linestyle='--',marker="x")

plt.legend(['United States','United Kingdom','China','India','Bhutan','Norway',"Ethiopia"],bbox_to_anchor=[0.95,0.95])


plt.title("Education inequality of selected countries over time")
plt.xlabel("Time")
plt.ylabel("Number")
# Out:
# Text(0, 0.5, 'Number')

# %%
LE= pd.read_csv("Inequality in life expectancy (%).csv")
LE= LE.set_index("Country")
LE_t=LE.T
LE_t
# Out:
# Country Afghanistan Albania Algeria Angola Antigua and Barbuda Argentina  \
# 2010           58.8    10.9    17.9   53.7                  ..      10.4
# 2011           50.9    11.2    14.5   46.1                  ..       9.7
# 2012           50.9    11.2    14.5   46.1                  ..       9.7
# 2013           34.3     9.9    16.7   46.2                   8       9.3
# 2014           34.3     9.9    16.7   46.2                   8       9.3
# 2015           35.7     9.9    18.6   46.2                 8.4        10
# 2016           28.4     9.2    15.1   33.8                 7.5       9.5
# 2017           28.4     9.2    15.1   33.8                 7.5       9.5
# 2018           28.3     7.2    14.1     32                 5.8       8.6
#
# Country Armenia Australia Austria Azerbaijan  ... Arab States  \
# 2010       15.3       4.7     4.5       23.8  ...        20.1
# 2011       14.9       4.7     4.2       20.6  ...        17.6
# ...

# %%
LE_t=LE_t.rename(columns={"United States":"US"})
LE_t=LE_t.rename(columns={"United Kingdom":"UK"})
LE_t['China'] = pd.to_numeric(LE_t['China'], errors='coerce')
LE_t['Bhutan'] = pd.to_numeric(LE_t['Bhutan'], errors='coerce')
LE_t['India'] = pd.to_numeric(LE_t['India'], errors='coerce')
LE_t['US'] = pd.to_numeric(LE_t['US'], errors='coerce')
LE_t['UK'] = pd.to_numeric(LE_t['UK'], errors='coerce')
LE_t['Ethiopia'] = pd.to_numeric(LE_t['Ethiopia'], errors='coerce')
LE_t['Norway'] = pd.to_numeric(LE_t['Norway'], errors='coerce')

# %%
plt.style.use('Solarize_Light2')
fig4=plt.figure(figsize=(8,6))
fig4=plt.plot(LE_t.US ,linestyle='--',marker="o")
fig4= plt.plot(LE_t.UK,linestyle='--',marker="x")
fig4= plt.plot(LE_t.China,linestyle=(0,(5,4,1,2)),marker=".")
fig4= plt.plot(LE_t.India,linestyle=(0,(5,4,1,2)),marker="+")
fig4= plt.plot(LE_t.Bhutan,linestyle='--',marker="o")
fig4= plt.plot(LE_t.Norway,linestyle=(0,(5,4,1,2)),marker="+")
fig4= plt.plot(LE_t.Ethiopia,linestyle='--',marker="x")

plt.legend(['United States','United Kingdom','China','India','Bhutan','Norway',"Ethiopia"],bbox_to_anchor=[0.95,0.95])


plt.title("Inequality in life expectancy of selected countries over time")
plt.xlabel("Time")
plt.ylabel("Percentage")
# Out:
# Text(0, 0.5, 'Percentage')

# %%
lh= pd.read_csv("Corr1.csv")
import seaborn as sns
plt.figure(figsize=(8,8))
corrMatrix= lh.corr()
corrMatrix
#sns.heatmap(corrMatrix, annot=True, cmap=sns.diverging_palette(200,8, as_cmap=True))
# Out:
#                  2018 LE  2018 Happiness
# 2018 LE         1.000000       -0.731789
# 2018 Happiness -0.731789        1.000000

# %%
lh
# Out:
#                                 Country  2018 LE  2018 Happiness
# 0                           Afghanistan     28.3           3.632
# 1                               Albania      7.2           4.586
# 2                               Algeria     14.1           5.295
# 3                                Angola     32.0           3.795
# 4                             Argentina      8.6           6.388
# ..                                  ...      ...             ...
# 145  Venezuela (Bolivarian Republic of)     17.1           4.806
# 146                            Viet Nam     12.9           5.103
# 147                               Yemen     24.7           3.355
# 148                              Zambia     26.5           4.377
# 149                            Zimbabwe     24.2           3.692
#
# [150 rows x 3 columns]

# %%
plt.style.use('dark_background')
sns.regplot(x="2018 Happiness",y="2018 LE",data=lh, marker="D")

# %%
ieh= pd.read_csv("corr2(income_ineq).csv")
ieh= ieh.set_index("Country or region")
ieh
# Out:
#                    happiness Score 2018 income ineq2018
# Country or region
# Afghanistan                       3.632              ..
# Albania                           4.586            13.2
# Algeria                           5.295            11.4
# Angola                            3.795            28.9
# Argentina                         6.388            25.8
# ...                                 ...             ...
# Venezuela                         4.806            25.2
# Vietnam                           5.103            18.1
# Yemen                             3.355            21.8
# Zambia                            4.377            48.6
# Zimbabwe                          3.692              27
#
# [144 rows x 2 columns]

# %%
ieh['happiness Score 2018'] = pd.to_numeric(ieh['happiness Score 2018'], errors='coerce')
ieh['income ineq2018'] = pd.to_numeric(ieh['income ineq2018'], errors='coerce')
corrMatrix2= ieh.corr()
corrMatrix2
# Out:
#                       happiness Score 2018  income ineq2018
# happiness Score 2018              1.000000        -0.311424
# income ineq2018                  -0.311424         1.000000

# %%
plt.style.use('ggplot')
sns.regplot(x="happiness Score 2018",y="income ineq2018",data=ieh, marker="D")
